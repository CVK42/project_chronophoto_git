# %% [markdown]
# moments colorimétriques

# %% [markdown]
# r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos_echantillon'

# %% [markdown]
# H entier

# %%
LES IMPORTS SONT A FAIRE!!!!!!!!

# %%
len(mean_V_values)
# Out:
# 7543

# %%
import pickle
with open('donnees_mean_H.pkl', 'wb') as fichier:
    pickle.dump(mean_H_values, fichier)
with open('donnees_mean_S.pkl', 'wb') as fichier:
    pickle.dump(mean_S_values, fichier)
with open('donnees_mean_V.pkl', 'wb') as fichier:
    pickle.dump(mean_V_values, fichier)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos'

# Listes pour stocker les moments colorimétriques et la moyenne de H
mean_H_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante H
        H = img_hsv[:, :, 0]

        # Calculer la moyenne de la composante H
        mean_H = np.mean(H)
        mean_H_values.append(mean_H)
        annees.append(annee)

# Calculer la moyenne et la médiane de mean_H_values sur chaque année
moyenne_annuelle_H = []
mediane_annuelle_H = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_H_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_H.append(np.mean(valeurs_annee))
    mediane_annuelle_H.append(np.median(valeurs_annee))

# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))

# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante H en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante H')
plt.scatter(annees_uniques, moyenne_annuelle_H, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante H en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante H')
plt.scatter(annees_uniques, mediane_annuelle_H, marker='+', c='blue')

plt.tight_layout()
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 310.92133235931396 secondes à s'exécuter.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos'

# Listes pour stocker les moments colorimétriques et la moyenne de H
mean_H_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante H
        H = img_hsv[:, :, 0]

        # Calculer la moyenne de la composante H
        mean_H = np.mean(H)
        mean_H_values.append(mean_H)
        annees.append(annee)
"""
# Calculer la moyenne et la médiane de mean_H_values sur chaque année
moyenne_annuelle_H = []
mediane_annuelle_H = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_H_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_H.append(np.mean(valeurs_annee))
    mediane_annuelle_H.append(np.median(valeurs_annee))

# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))"""
plt.scatter(annees,mean_H_values,marker='+')
"""
# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante H en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante H')
plt.scatter(annees_uniques, moyenne_annuelle_H, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante H en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante H')
plt.scatter(annees_uniques, mediane_annuelle_H, marker='+', c='blue')

plt.tight_layout()"""
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 240.6301498413086 secondes à s'exécuter.

# %%
print(len(annees), len(mean_H_values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(len(annees), len(mean_H_values))
#
# NameError: name 'annees' is not defined

# %% [markdown]
# S entier

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos'

# Listes pour stocker les moments colorimétriques et la moyenne de S
mean_S_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante S
        S = img_hsv[:, :, 1]

        # Calculer la moyenne de la composante S
        mean_S = np.mean(S)
        mean_S_values.append(mean_S)
        annees.append(annee)

# Calculer la moyenne et la médiane de mean_S_values sur chaque année
moyenne_annuelle_S = []
mediane_annuelle_S = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_S_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_S.append(np.mean(valeurs_annee))
    mediane_annuelle_S.append(np.median(valeurs_annee))
    
# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))

# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante S en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante S')
plt.scatter(annees_uniques, moyenne_annuelle_S, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante S en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante S')
plt.scatter(annees_uniques, mediane_annuelle_S, marker='+', c='blue')

plt.tight_layout()
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 246.2396638393402 secondes à s'exécuter.

# %% [markdown]
# V entier

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos'

# Listes pour stocker les moments colorimétriques et la moyenne de S
mean_S_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante S
        S = img_hsv[:, :, 1]

        # Calculer la moyenne de la composante S
        mean_S = np.mean(S)
        mean_S_values.append(mean_S)
        annees.append(annee)
"""
# Calculer la moyenne et la médiane de mean_S_values sur chaque année
moyenne_annuelle_S = []
mediane_annuelle_S = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_S_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_S.append(np.mean(valeurs_annee))
    mediane_annuelle_S.append(np.median(valeurs_annee))"""

plt.scatter(annees,mean_S_values,marker='+')

"""
# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))

# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante S en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante S')
plt.scatter(annees_uniques, moyenne_annuelle_S, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante S en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante S')
plt.scatter(annees_uniques, mediane_annuelle_S, marker='+', c='blue')

plt.tight_layout()"""
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 236.7886519432068 secondes à s'exécuter.

# %%
print(len(annees), len(mean_S_values))
# Out:
# 246 246

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos'

# Listes pour stocker les moments colorimétriques et la moyenne de V
mean_V_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante V
        V = img_hsv[:, :, 2]

        # Calculer la moyenne de la composante V
        mean_V = np.mean(V)
        mean_V_values.append(mean_V)
        annees.append(annee)
        
plt.scatter(annees,mean_V_values,marker='+')

"""# Calculer la moyenne et la médiane de mean_V_values sur chaque année
moyenne_annuelle_V = []
mediane_annuelle_V = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_V_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_V.append(np.mean(valeurs_annee))
    mediane_annuelle_V.append(np.median(valeurs_annee))

# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))

# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante V en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante V')
plt.scatter(annees_uniques, moyenne_annuelle_V, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante V en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante V')
plt.scatter(annees_uniques, mediane_annuelle_V, marker='+', c='blue')

plt.tight_layout()"""
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 235.3864130973816 secondes à s'exécuter.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

# Chemin vers le dossier contenant les images
dossier_images = r'C:\Users\chris\OneDrive\Documents\Python Scripts\chronophoto\photos_echantillon'

# Listes pour stocker les moments colorimétriques et la moyenne de V
mean_V_values = []
annees = []

# Mesurer le temps de début
temps_debut = time.time()

# Parcourir les fichiers dans le dossier
for fichier in os.listdir(dossier_images):
    if fichier.lower().endswith(('.jpg', '.jpeg')):
        chemin_image = os.path.join(dossier_images, fichier)

        # Extraire l'année du nom du fichier
        annee = int(fichier.split('-')[0])

        # Charger l'image en RGB
        img = cv2.imread(chemin_image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Convertir l'image en HSV
        img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

        # Extraire la composante V
        V = img_hsv[:, :, 2]

        # Calculer la moyenne de la composante V
        mean_V = np.mean(V)
        mean_V_values.append(mean_V)
        annees.append(annee)

# Calculer la moyenne et la médiane de mean_V_values sur chaque année
moyenne_annuelle_V = []
mediane_annuelle_V = []
annees_uniques = np.unique(annees)

for annee_unique in annees_uniques:
    valeurs_annee = [mean_V_values[i] for i, annee in enumerate(annees) if annee == annee_unique]
    moyenne_annuelle_V.append(np.mean(valeurs_annee))
    mediane_annuelle_V.append(np.median(valeurs_annee))

# Tracer les graphiques de la moyenne et de la médiane côte à côte
plt.figure(figsize=(10, 5))

# Graphique de la moyenne
plt.subplot(1, 2, 1)
plt.title('Moyenne de la composante V en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Moyenne de la composante V')
plt.scatter(annees_uniques, moyenne_annuelle_V, marker='+', c='red')

# Graphique de la médiane
plt.subplot(1, 2, 2)
plt.title('Médiane de la composante V en fonction de l\'année')
plt.xlabel('Année')
plt.ylabel('Médiane de la composante V')
plt.scatter(annees_uniques, mediane_annuelle_V, marker='+', c='blue')

plt.tight_layout()
plt.show()

# Mesurer le temps de fin
temps_fin = time.time()
temps_execution = temps_fin - temps_debut
print("Le programme a mis", temps_execution, "secondes à s'exécuter.")
# Out:
# Le programme a mis 61.38037991523743 secondes à s'exécuter.
